# %% [markdown]
# <a href="https://colab.research.google.com/github/ChutikarnJuntaramanee/DSA201-Data-Wrangling/blob/main/DW_API5_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd

# %%
#1 Public APIs
rawdata1 = requests.get('https://api.publicapis.org/entries')
print(rawdata1.json())
# Out:
# {'count': 940, 'entries': [{'API': 'Axolotl', 'Description': 'Collection of axolotl pictures and facts', 'Auth': '', 'HTTPS': True, 'Cors': 'unknown', 'Link': 'https://theaxolotlapi.netlify.app/', 'Category': 'Animals'}, {'API': 'Cat Facts', 'Description': 'Daily cat facts', 'Auth': '', 'HTTPS': True, 'Cors': 'no', 'Link': 'https://alexwohlbruck.github.io/cat-facts/', 'Category': 'Animals'}, {'API': 'Cataas', 'Description': 'Cat as a service (cats pictures and gifs)', 'Auth': '', 'HTTPS': True, 'Cors': 'unknown', 'Link': 'https://cataas.com/', 'Category': 'Animals'}, {'API': 'catAPI', 'Description': 'Random pictures of cats', 'Auth': '', 'HTTPS': True, 'Cors': 'yes', 'Link': 'https://github.com/ThatCopy/catAPI/wiki/Usage', 'Category': 'Animals'}, {'API': 'Cats', 'Description': 'Pictures of cats from Tumblr', 'Auth': 'apiKey', 'HTTPS': True, 'Cors': 'unknown', 'Link': 'https://docs.thecatapi.com/', 'Category': 'Animals'}, {'API': 'Dog Facts', 'Description': 'Random dog facts', 'Auth':
# ...

# %%
import json

# %%
# Assign new variable
rawdata1_json = rawdata1.content

# %%
data1_json = json.loads(rawdata1_json)
data1_json
# Out:
# {'count': 940,
#  'entries': [{'API': 'Axolotl',
#    'Auth': '',
#    'Category': 'Animals',
#    'Cors': 'unknown',
#    'Description': 'Collection of axolotl pictures and facts',
#    'HTTPS': True,
#    'Link': 'https://theaxolotlapi.netlify.app/'},
#   {'API': 'Cat Facts',
#    'Auth': '',
#    'Category': 'Animals',
#    'Cors': 'no',
#    'Description': 'Daily cat facts',
#    'HTTPS': True,
#    'Link': 'https://alexwohlbruck.github.io/cat-facts/'},
#   {'API': 'Cataas',
#    'Auth': '',
#    'Category': 'Animals',
#    'Cors': 'unknown',
#    'Description': 'Cat as a service (cats pictures and gifs)',
#    'HTTPS': True,
#    'Link': 'https://cataas.com/'},
#   {'API': 'catAPI',
#    'Auth': '',
#    'Category': 'Animals',
#    'Cors': 'yes',
#    'Description': 'Random pictures of cats',
#    'HTTPS': True,
#    'Link': 'https://github.com/ThatCopy/catAPI/wiki/Usage'},
#   {'API': 'Cats',
#    'Auth': 'apiKey',
#    'Category': 'Animals',
#    'Cors': 'unknown',
# ...

# %%
Data1 = pd.DataFrame(data1_json)
Data1
# Out:
#      count                                            entries
# 0      940  {'API': 'Axolotl', 'Description': 'Collection ...
# 1      940  {'API': 'Cat Facts', 'Description': 'Daily cat...
# 2      940  {'API': 'Cataas', 'Description': 'Cat as a ser...
# 3      940  {'API': 'catAPI', 'Description': 'Random pictu...
# 4      940  {'API': 'Cats', 'Description': 'Pictures of ca...
# ..     ...                                                ...
# 935    940  {'API': 'Troposphere', 'Description': 'Global ...
# 936    940  {'API': 'Visual Crossing', 'Description': 'Glo...
# 937    940  {'API': 'weather-api', 'Description': 'A RESTf...
# 938    940  {'API': 'Weatherbit', 'Description': 'Weather'...
# 939    940  {'API': 'wttr', 'Description': ':partly_sunny:...
#
# [940 rows x 2 columns]

# %%
Data1.columns
# Out:
# Index(['count', 'entries'], dtype='object')

# %%
Data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 940 entries, 0 to 939
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   count    940 non-null    int64
#  1   entries  940 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 14.8+ KB

# %%
Data1.isnull()
# Out:
#      count  entries
# 0    False    False
# 1    False    False
# 2    False    False
# 3    False    False
# 4    False    False
# ..     ...      ...
# 935  False    False
# 936  False    False
# 937  False    False
# 938  False    False
# 939  False    False
#
# [940 rows x 2 columns]

# %%
df1 = pd.DataFrame(data1_json['entries'])
df1
# Out:
#                  API  ... Category
# 0            Axolotl  ...  Animals
# 1          Cat Facts  ...  Animals
# 2             Cataas  ...  Animals
# 3             catAPI  ...  Animals
# 4               Cats  ...  Animals
# ..               ...  ...      ...
# 935      Troposphere  ...  Weather
# 936  Visual Crossing  ...  Weather
# 937      weather-api  ...  Weather
# 938       Weatherbit  ...  Weather
# 939             wttr  ...  Weather
#
# [940 rows x 7 columns]

# %%
Data1.isnull().sum()
# Out:
# count      0
# entries    0
# dtype: int64

# %%
df1.drop(['Auth', 'HTTPS', 'Cors', 'Link'], axis ='columns', inplace = True)
df1
# Out:
#                  API  ... Category
# 0            Axolotl  ...  Animals
# 1          Cat Facts  ...  Animals
# 2             Cataas  ...  Animals
# 3             catAPI  ...  Animals
# 4               Cats  ...  Animals
# ..               ...  ...      ...
# 935      Troposphere  ...  Weather
# 936  Visual Crossing  ...  Weather
# 937      weather-api  ...  Weather
# 938       Weatherbit  ...  Weather
# 939             wttr  ...  Weather
#
# [940 rows x 3 columns]

# %%
cat = df1['Category']
Data1_cat = pd.Series(cat)
Data1_cat.value_counts()
# Out:
# Development                     82
# Geocoding                       66
# Games & Comics                  66
# Transportation                  52
# Government                      44
# Cryptocurrency                  39
# Science & Math                  28
# Social                          28
# Music                           28
# Video                           26
# Weather                         24
# Open Data                       23
# Sports & Fitness                23
# Personality                     23
# Security                        22
# Finance                         21
# Health                          20
# Animals                         18
# Books                           18
# Photography                     16
# Calendar                        16
# Test Data                       16
# Machine Learning                16
# Food & Drink                    16
# Art & Design                    14
# News                            14
# Jobs                            14
# ...

# %%
#Bar graph
Data1_cat.value_counts().plot.bar(x ='API', y='Category', figsize = (15,5), xlabel="API", ylabel="Category", title= "Number of API by Category")
plt.show()

# %%
#2 Data USA
rawdata2 = requests.get('https://datausa.io/api/data?drilldowns=Nation&measures=Population')
print(rawdata2.json())
# Out:
# {'data': [{'ID Nation': '01000US', 'Nation': 'United States', 'ID Year': 2019, 'Year': '2019', 'Population': 328239523, 'Slug Nation': 'united-states'}, {'ID Nation': '01000US', 'Nation': 'United States', 'ID Year': 2018, 'Year': '2018', 'Population': 327167439, 'Slug Nation': 'united-states'}, {'ID Nation': '01000US', 'Nation': 'United States', 'ID Year': 2017, 'Year': '2017', 'Population': 325719178, 'Slug Nation': 'united-states'}, {'ID Nation': '01000US', 'Nation': 'United States', 'ID Year': 2016, 'Year': '2016', 'Population': 323127515, 'Slug Nation': 'united-states'}, {'ID Nation': '01000US', 'Nation': 'United States', 'ID Year': 2015, 'Year': '2015', 'Population': 321418821, 'Slug Nation': 'united-states'}, {'ID Nation': '01000US', 'Nation': 'United States', 'ID Year': 2014, 'Year': '2014', 'Population': 318857056, 'Slug Nation': 'united-states'}, {'ID Nation': '01000US', 'Nation': 'United States', 'ID Year': 2013, 'Year': '2013', 'Population': 316128839, 'Slug Nation': 'unit
# ...

# %%
# Assign new variable
rawdata2_json = rawdata2.content

# %%
data2_json = json.loads(rawdata2_json)
data2_json
# Out:
# {'data': [{'ID Nation': '01000US',
#    'ID Year': 2019,
#    'Nation': 'United States',
#    'Population': 328239523,
#    'Slug Nation': 'united-states',
#    'Year': '2019'},
#   {'ID Nation': '01000US',
#    'ID Year': 2018,
#    'Nation': 'United States',
#    'Population': 327167439,
#    'Slug Nation': 'united-states',
#    'Year': '2018'},
#   {'ID Nation': '01000US',
#    'ID Year': 2017,
#    'Nation': 'United States',
#    'Population': 325719178,
#    'Slug Nation': 'united-states',
#    'Year': '2017'},
#   {'ID Nation': '01000US',
#    'ID Year': 2016,
#    'Nation': 'United States',
#    'Population': 323127515,
#    'Slug Nation': 'united-states',
#    'Year': '2016'},
#   {'ID Nation': '01000US',
#    'ID Year': 2015,
#    'Nation': 'United States',
#    'Population': 321418821,
#    'Slug Nation': 'united-states',
#    'Year': '2015'},
#   {'ID Nation': '01000US',
#    'ID Year': 2014,
#    'Nation': 'United States',
#    'Population': 318857056,
# ...

# %%
data_2 = data2_json['data']
Data2 = pd.DataFrame(data_2)
Data2
# Out:
#   ID Nation         Nation  ID Year  Year  Population    Slug Nation
# 0   01000US  United States     2019  2019   328239523  united-states
# 1   01000US  United States     2018  2018   327167439  united-states
# 2   01000US  United States     2017  2017   325719178  united-states
# 3   01000US  United States     2016  2016   323127515  united-states
# 4   01000US  United States     2015  2015   321418821  united-states
# 5   01000US  United States     2014  2014   318857056  united-states
# 6   01000US  United States     2013  2013   316128839  united-states

# %%
Data2.drop(['ID Year', 'Slug Nation'],axis ='columns', inplace= True)
Data2
# Out:
#   ID Nation         Nation  Year  Population
# 0   01000US  United States  2019   328239523
# 1   01000US  United States  2018   327167439
# 2   01000US  United States  2017   325719178
# 3   01000US  United States  2016   323127515
# 4   01000US  United States  2015   321418821
# 5   01000US  United States  2014   318857056
# 6   01000US  United States  2013   316128839

# %%
Data2.sort_values("Year")
# Out:
#   ID Nation         Nation  Year  Population
# 6   01000US  United States  2013   316128839
# 5   01000US  United States  2014   318857056
# 4   01000US  United States  2015   321418821
# 3   01000US  United States  2016   323127515
# 2   01000US  United States  2017   325719178
# 1   01000US  United States  2018   327167439
# 0   01000US  United States  2019   328239523

# %%
Data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID Nation   7 non-null      object
#  1   Nation      7 non-null      object
#  2   Year        7 non-null      object
#  3   Population  7 non-null      int64
# dtypes: int64(1), object(3)
# memory usage: 352.0+ bytes

# %%
data_year_type = {'Year' : int}
Data2 = Data2.astype(data_year_type)
Data2.dtypes
# Out:
# ID Nation     object
# Nation        object
# Year           int64
# Population     int64
# dtype: object

# %%
#Line graph2 Data USA
import matplotlib.pyplot as plt
Data2.plot(x ='Year', y='Population', figsize = (15,5), xlabel="Year", ylabel="Population", title= "Number of population by year on Data USA")

# %%
#pie graph
population = Data2['Population']
year = Data2['Year']
explode = (0.2, 0.2, 0, 0, 0, 0, 0)
colors = ['#009392','#39B185','#9CCB86', '#E9E29C','#EEB479','#E88471', '#CF597E']
plt.pie(population, labels=year, autopct='%1.1f%%', startangle=120, shadow = True, colors=colors, explode=explode)
plt.title('Data USA Population till 2019')
# Out:
# Text(0.5, 1.0, 'Data USA Population till 2019')

# %%
#3 CoinDesk
rawdata3 = requests.get('https://api.coindesk.com/v1/bpi/currentprice.json')
print(rawdata3.json())
# Out:
# {'time': {'updated': 'Sep 24, 2021 13:20:00 UTC', 'updatedISO': '2021-09-24T13:20:00+00:00', 'updateduk': 'Sep 24, 2021 at 14:20 BST'}, 'disclaimer': 'This data was produced from the CoinDesk Bitcoin Price Index (USD). Non-USD currency data converted using hourly conversion rate from openexchangerates.org', 'chartName': 'Bitcoin', 'bpi': {'USD': {'code': 'USD', 'symbol': '&#36;', 'rate': '41,136.7383', 'description': 'United States Dollar', 'rate_float': 41136.7383}, 'GBP': {'code': 'GBP', 'symbol': '&pound;', 'rate': '30,100.8621', 'description': 'British Pound Sterling', 'rate_float': 30100.8621}, 'EUR': {'code': 'EUR', 'symbol': '&euro;', 'rate': '35,139.6189', 'description': 'Euro', 'rate_float': 35139.6189}}}

# %%
rawdata3_json = rawdata3.content

# %%
data3_json = json.loads(rawdata3_json)
data3_json
# Out:
# {'bpi': {'EUR': {'code': 'EUR',
#    'description': 'Euro',
#    'rate': '35,139.6189',
#    'rate_float': 35139.6189,
#    'symbol': '&euro;'},
#   'GBP': {'code': 'GBP',
#    'description': 'British Pound Sterling',
#    'rate': '30,100.8621',
#    'rate_float': 30100.8621,
#    'symbol': '&pound;'},
#   'USD': {'code': 'USD',
#    'description': 'United States Dollar',
#    'rate': '41,136.7383',
#    'rate_float': 41136.7383,
#    'symbol': '&#36;'}},
#  'chartName': 'Bitcoin',
#  'disclaimer': 'This data was produced from the CoinDesk Bitcoin Price Index (USD). Non-USD currency data converted using hourly conversion rate from openexchangerates.org',
#  'time': {'updated': 'Sep 24, 2021 13:20:00 UTC',
#   'updatedISO': '2021-09-24T13:20:00+00:00',
#   'updateduk': 'Sep 24, 2021 at 14:20 BST'}}

# %%
Data3 = pd.DataFrame(data3_json)
Data3
# Out:
#                                  time  ...                                                bpi
# updated     Sep 24, 2021 13:20:00 UTC  ...                                                NaN
# updatedISO  2021-09-24T13:20:00+00:00  ...                                                NaN
# updateduk   Sep 24, 2021 at 14:20 BST  ...                                                NaN
# USD                               NaN  ...  {'code': 'USD', 'symbol': '&#36;', 'rate': '41...
# GBP                               NaN  ...  {'code': 'GBP', 'symbol': '&pound;', 'rate': '...
# EUR                               NaN  ...  {'code': 'EUR', 'symbol': '&euro;', 'rate': '3...
#
# [6 rows x 4 columns]

# %%
Data3.isnull().sum()
# Out:
# time          3
# disclaimer    0
# chartName     0
# bpi           3
# dtype: int64

# %%
Data3 = pd.DataFrame(data3_json['bpi'])
Data3
# Out:
#                               USD                     GBP          EUR
# code                          USD                     GBP          EUR
# symbol                      &#36;                 &pound;       &euro;
# rate                  41,136.7383             30,100.8621  35,139.6189
# description  United States Dollar  British Pound Sterling         Euro
# rate_float                41136.7                 30100.9      35139.6

# %%
#Transpost Data3
Data3_tsp = Data3.transpose()
Data3_tsp.drop(['code', 'symbol','rate' ],axis ='columns')
Data3_tsp
# Out:
#     code   symbol         rate             description rate_float
# USD  USD    &#36;  41,136.7383    United States Dollar    41136.7
# GBP  GBP  &pound;  30,100.8621  British Pound Sterling    30100.9
# EUR  EUR   &euro;  35,139.6189                    Euro    35139.6

# %%
#Check data type
Data3_tsp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, USD to EUR
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   code         3 non-null      object
#  1   symbol       3 non-null      object
#  2   rate         3 non-null      object
#  3   description  3 non-null      object
#  4   rate_float   3 non-null      object
# dtypes: object(5)
# memory usage: 224.0+ bytes

# %%
rate = Data3_tsp['rate_float']
Data3_rate = pd.Series(rate)
Data3_rate.value_counts()
# Out:
# 30100.8621    1
# 35139.6189    1
# 41136.7383    1
# Name: rate_float, dtype: int64

# %%
#Scaboarn
import seaborn as sns
sns.boxplot(y='rate_float', x='description', 
                 data=Data3_tsp, 
                 width=0.5,
                 palette="colorblind")
plt.title("Coindesk")
plt.xlabel("Country")
plt.ylabel("Rate")
# Out:
# Text(0, 0.5, 'Rate')

# %%
#Line graph
import matplotlib.pyplot as plt
Data3_tsp.plot(x ='description', y='rate_float', figsize = (15,5), xlabel="Country", ylabel="Rate", title= "Number of ra by year on Data USA")

# %%
#4 Nationalize.io
rawdata4 = requests.get('https://api.nationalize.io?name=nathaniel')
print(rawdata4.json())
# Out:
# {'name': 'nathaniel', 'country': [{'country_id': 'GH', 'probability': 0.3306489516462087}, {'country_id': 'US', 'probability': 0.21465914776725203}, {'country_id': 'PH', 'probability': 0.1657076043373859}]}

# %%
rawdata4_json = rawdata4.content

# %%
data4_json = json.loads(rawdata4_json)
data4_json
# Out:
# {'country': [{'country_id': 'GH', 'probability': 0.3306489516462087},
#   {'country_id': 'US', 'probability': 0.21465914776725203},
#   {'country_id': 'PH', 'probability': 0.1657076043373859}],
#  'name': 'nathaniel'}

# %%
Data4 = pd.DataFrame(data4_json)
Data4
# Out:
#         name                                            country
# 0  nathaniel  {'country_id': 'GH', 'probability': 0.33064895...
# 1  nathaniel  {'country_id': 'US', 'probability': 0.21465914...
# 2  nathaniel  {'country_id': 'PH', 'probability': 0.16570760...

# %%
Data4 = pd.DataFrame(data4_json['country'])
Data4
# Out:
#   country_id  probability
# 0         GH     0.330649
# 1         US     0.214659
# 2         PH     0.165708

# %%
Data4.rename(columns={'country_id':'Country', 'probability':'Probability'}, inplace=True)

# %%
#Scatter
import seaborn as sns
sns.scatterplot(x='Country',y='Probability', data =Data4)
plt.title("Probability of each country")
plt.show()

# %%
#5 Zippopotam
rawdata5 = requests.get('https://api.zippopotam.us/us/33162')
print(rawdata5.json())
# Out:
# {'post code': '33162', 'country': 'United States', 'country abbreviation': 'US', 'places': [{'place name': 'Miami', 'longitude': '-80.183', 'state': 'Florida', 'state abbreviation': 'FL', 'latitude': '25.9286'}]}

# %%
rawdata5_json = rawdata5.content

# %%
data5_json = json.loads(rawdata5_json)
data5_json
# Out:
# {'country': 'United States',
#  'country abbreviation': 'US',
#  'places': [{'latitude': '25.9286',
#    'longitude': '-80.183',
#    'place name': 'Miami',
#    'state': 'Florida',
#    'state abbreviation': 'FL'}],
#  'post code': '33162'}

# %%
Data5_1 = pd.DataFrame(data5_json)
Data5_1
# Out:
#   post code  ...                                             places
# 0     33162  ...  {'place name': 'Miami', 'longitude': '-80.183'...
#
# [1 rows x 4 columns]

# %%
Data5_1.drop(['country abbreviation','places'], axis ='columns', inplace = True)
Data5_1
# Out:
#   post code        country
# 0     33162  United States

# %%
Data5_2 = pd.DataFrame(data5_json['places'])
Data5_2
# Out:
#   place name longitude    state state abbreviation latitude
# 0      Miami   -80.183  Florida                 FL  25.9286

# %%
Data5_2.drop(['state abbreviation'], axis ='columns', inplace = True)
Data5_2
# Out:
#   place name longitude    state latitude
# 0      Miami   -80.183  Florida  25.9286

# %%
Data5 = pd.merge(Data5_1, Data5_2, right_index=True, left_index=True)
Data5
# Out:
#   post code        country place name longitude    state latitude
# 0     33162  United States      Miami   -80.183  Florida  25.9286

# %%
import folium
m  = folium.Map(
 location=[25.1286, -78.183],
 zoom_start=5,)

folium.Marker(
 location=[25.9286, -80.183],
 popup='Miami',
 icon=folium.Icon(color='red')
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.co
# ...
