# %% [markdown]
# <a href="https://colab.research.google.com/github/ChutikarnJuntaramanee/DSA201-Data-Wrangling/blob/main/Listwise_Deletion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import json
import requests

# %%
Listwise_Deletion=pd.read_csv('fishdata.csv', engine='python')
Listwise_Deletion
# Out:
#           Year  Month  Day  ...  external temp  humidity  internal temperature
# 0       2020.0    6.0   18  ...           95.0     27.25                  4.39
# 1       2020.0    6.0   18  ...           95.0     27.25                  4.38
# 2       2020.0    6.0   18  ...           95.0     27.25                  4.42
# 3       2020.0    6.0   18  ...           95.0     27.25                  4.39
# 4       2020.0    6.0   18  ...           95.0     27.25                  4.42
# ...        ...    ...  ...  ...            ...       ...                   ...
# 811942  2020.0   10.0   17  ...           95.0     29.06                  4.10
# 811943  2020.0   10.0   17  ...           95.0     29.06                  4.10
# 811944  2020.0   10.0   17  ...           95.0     29.06                  4.11
# 811945  2020.0   10.0   17  ...           95.0     29.06                  4.10
# 811946  2020.0   10.0   17  ...           95.0     29.06                  4.11
#
# ...

# %%
Listwise_Deletion.isnull().sum()
# Out:
# Year                       0
# Month                      0
# Day                        0
# hour                       0
# minute                     0
# second                     0
# carbon monoxide         1748
# external temperature      75
# PM 2.5                    96
# external temp            104
# humidity                 104
# internal temperature    4539
# dtype: int64

# %%
Listwise_Deletion.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 811947 entries, 0 to 811946
# Data columns (total 12 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Year                  811947 non-null  float64
#  1   Month                 811947 non-null  float64
#  2   Day                   811947 non-null  int64
#  3   hour                  811947 non-null  int64
#  4   minute                811947 non-null  float64
#  5   second                811947 non-null  float64
#  6   carbon monoxide       810199 non-null  object
#  7   external temperature  811872 non-null  float64
#  8   PM 2.5                811851 non-null  float64
#  9   external temp         811843 non-null  float64
#  10  humidity              811843 non-null  float64
#  11  internal temperature  807408 non-null  float64
# dtypes: float64(9), int64(2), object(1)
# memory usage: 74.3+ MB

# %%
Listwise_Deletion['carbon monoxide'] = Listwise_Deletion['carbon monoxide'].apply(pd.to_numeric, errors='coerce')

# %%
import matplotlib.pyplot as plt
Listwise_Deletion.plot(y='carbon monoxide', use_index=True, figsize=(6,6))

# %%
Listwise_Deletion.plot(y='external temperature',color='green', use_index=True, figsize=(6,6))

# %%
Listwise_Deletion.plot(y='PM 2.5', use_index=True, figsize=(6,6))

# %%
Listwise_Deletion.plot(y='humidity', color='orange', use_index=True, figsize=(6,6))

# %%
Listwise_Deletion.plot(y='external temp', color='red', use_index=True, figsize=(6,6))

# %%
Listwise_Deletion.plot(y='internal temperature', color='purple', use_index=True, figsize=(6,6))

# %%
import missingno as msno
msno.matrix(Listwise_Deletion)

# %%
Listwise_Deletion.dropna(subset=['carbon monoxide'],how='any',inplace=True)

# %%
Listwise_Deletion.dropna(subset=['external temperature'],how='any',inplace=True)

# %%
Listwise_Deletion.dropna(subset=['PM 2.5'],how='any',inplace=True)

# %%
Listwise_Deletion.dropna(subset=['external temp'],how='any',inplace=True)

# %%
Listwise_Deletion.dropna(subset=['humidity'],how='any',inplace=True)

# %%
Listwise_Deletion.dropna(subset=['internal temperature'],how='any',inplace=True)

# %%
Listwise_Deletion.isnull().sum()
# Out:
# Year                    0
# Month                   0
# Day                     0
# hour                    0
# minute                  0
# second                  0
# carbon monoxide         0
# external temperature    0
# PM 2.5                  0
# external temp           0
# humidity                0
# internal temperature    0
# dtype: int64

# %%
msno.matrix(Listwise_Deletion)

# %%
Listwise_Deletion.plot(y='carbon monoxide', use_index=True, figsize=(6,6))

# %%
Listwise_Deletion.plot(y='external temperature',color='green', use_index=True, figsize=(6,6))

# %%
Listwise_Deletion.plot(y='humidity',color='orange', use_index=True, figsize=(6,6))

# %%
Listwise_Deletion.plot(y='external temp', color='red', use_index=True, figsize=(6,6))

# %%
Listwise_Deletion.plot(y='internal temperature', color='purple', use_index=True, figsize=(6,6))
